# %% [markdown]
# <h1>Introduction to Programming</h1>

# %% [markdown]
# <h3>What is a computer program?</h3>

# %% [markdown]
# A computer is an inanimate object which is completely incapable of doing anything except what it is told to do.  A computer program is a set of instructions which tell the computer what to do.  Everything you have ever done with a computer has involved executing a computer program that someone wrote.  (More likely, it was a tapestry of interacting programs working in concert.)

# %% [markdown]
# Here is a simple computer program (written in a programming language called *Python*).  Click on the cell below and press `shift + enter` to run it.

# %%
seconds_in_minute = 60
minutes_in_hour = 60
hours_in_day = 24
days_in_week = 7
weeks_in_month = 4 + 1/3
months_in_year = 12

minutes_in_week = minutes_in_hour * hours_in_day * days_in_week
print(minutes_in_week)
# Out:
# 10080

# %% [markdown]
# Here's another one:

# %%
seconds_in_day = seconds_in_minute * minutes_in_hour * hours_in_day
print(seconds_in_day)
# Out:
# 86400

# %% [markdown]
# See if you can write a computer program which computes the number of hours in a year below:

# %%
hours_in_year = 
print(hours_in_year)

# %% [markdown]
# <h3>What can computer programs do?</h3>

# %% [markdown]
# Many, many things.  Here is some stuff that we'll learn how to do here:
#
# <ul>
#     <li>Do very hard computations quickly</li>
#     <li>Gather and process huge amounts of data, e.g. tweets, Wikipedia pages, or stock prices</li>
#     <li>Perform complex manipulations with text documents</li>
#     <li>Automate complex or repetitive tasks</li>
#     <li><strike>Conquer planet earth and enslave its inhabitants</strike></li>
# </ul>

# %% [markdown]
# <h3>What can't computer programs do?</h3>

# %% [markdown]
# <ul>
#     <li>Think</li>
#     <li>Feel</li>
#     <li>Love</li>
#     <li>Anything that a human hasn't explicitly told it to do</li>
# </ul>

# %% [markdown]
# <h3>Why learn to code?</h3>

# %% [markdown]
# <ul>
#     <li>It's fun (seriously!) and you'll learn a lot</li>
#     <li>If you work with any sort of data, programming is the most powerful and flexible skill you can have (fuck Excel)</li>
#     <li>Learn how computers / the internet work, why they break, and how to fix them</li>
#     <li>Automate your job!</li>
#     <li>Skill up for another job?</li>
# </ul>
#
# Everyone sitting in this room can learn how to code with enough time and patience.  Whether or not it's worth the effort is up to you!

# %% [markdown]
# <h3>How these lessons are going to work</h3>

# %% [markdown]
# <ol>
#     <li>Over the next few weeks we're going to try to teach the fundamentals of programming and the basics of Python syntax.</li>
#     <li>As we go, we're going to apply what we learn to Brandwatch data in order to provide some context.</li>
#     <li>Once we all have a reasonably solid foundation, we'll pick projects to work on either individually or in small groups.  We'll explore additional concepts as they arise in these projects.</li>
# </ol>
