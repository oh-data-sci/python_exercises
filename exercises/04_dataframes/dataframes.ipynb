# %% [markdown]
# # introducing dataframes
#
# a dataframe is best described as a table with particular properties:
#
# - there is one row per observation (what defines an observation may vary case by case).
# - there is one column per measure.
# - all values of each column (i.e. all rows) must be the same data type.
# - the columns may be (most often are) of different data type.
#
# together these properties define "tidy data". tidy data is the preferred format to work with when it comes to modeling and analysis. many useful modules and functions assume the input to be in tidy format and also shape their output to be tidy. this offers the ability to string these functions together to make complex manipulations. again, the `pandas` module makes working with dataframes easier so we will be using that.
#
# # manipulating dataframes
#
# today we will see how we can manipulate dataframes with pandas to
# - trim,
# - filter,
# - summarise,
# - augment
# pandas dataframes. (later we will look into joining dataframes, but we won't have time for it now).
#
#
# # today's exercise:
# use what you have learned in your previous solutions to read in the new york rodent inspection data as a `pandas` dataframe, and then augment that dataframe with wait time (interval between inspection and approval), weekday,  and iso-week of inspection. also add a new column, `season` of the inspection date (defined as: dec-feb, inclusive, is winter, mar-may is spring, jun-aug is summer, sep-nov is fall).
#
# then answer the following questions:
# - between the dates of 2010-01-01 and 2010-03-31, what was the daily average number of inspections?
# - between the dates of 2010-01-01 and 2010-03-31, which weekday had the greatest number of inspections?
# - between the dates of 2010-01-01 and 2010-03-31, which weekday had the least number of inspections?
#
# if you are confident that you can already solve this, the rest of the session is not much use to you.
#
# as a bonus we should be able to answer these further questions
# - which weekday has the longest average wait time for approval in the winter? (let's define the seasons as: (dec-feb is winter, mar-may is spring, jun-aug is summer, sep-nov is fall).
# - which weekday has the longest average wait time for approval in the summer?
# - which season has the greatest number of inspections?
# - which season has the greatest number of distinct dates ...
#     + a) in the data set
#     + b) in the calendar?
# - which borough has the greatest difference in the number of inspections in the spring vs in the fall?
# - count the number of inspections per [iso-week](https://en.wikipedia.org/wiki/ISO_week_date). find the week with the greatest number of inspections. for that week, and that week only, count the inspections by day-of-week.

# %%
# let us start by importing the modules we need.
import pandas as pd
import datetime

# %%
#filename_csv = 'NY_rodent_inspections_sample_small.csv' # for initial testing
#filename_csv = 'NY_rodent_inspections_sample_medium.csv' # for further consideration
filename_csv = 'NY_rodent_inspections_sample.csv' # for full on run

# %% [markdown]
# when you read in a data file with `read_csv()`, `pandas` will automatically convert it into a dataframe for you.

# %%
rodent_df = pd.read_csv(filename_csv) 
# inspect the data frame
rodent_df.shape
# Out:
# (9999, 20)

# %%
rodent_df.tail(10)
# Out:
#      INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID    JOB_ID  JOB_PROGRESS  \
# 9989            BAIT                        23815  PO124451             4
# 9990            BAIT                        23816  PO124452             4
# 9991            BAIT                        23817  PO124205             4
# 9992            BAIT                        23820  PO123787             4
# 9993            BAIT                        23823  PO123783             4
# 9994            BAIT                        23826  PO107033             5
# 9995            BAIT                        23827   PO69910             6
# 9996            BAIT                        23828   PO37474             8
# 9997            BAIT                        23830   PO84268             5
# 9998            BAIT                        23831   PO59293            11
#
#              BBL  BORO_CODE  BLOCK  LOT HOUSE_NUMBER           STREET_NAME  \
# 9989  2026970019          2   2697   19          939       EAST 163 STREET
# 9990  2026970022          2   2697   22          915         DAWSON STREET
# 9991  2026990060          2   2699   60          937    WESTCHESTER AVENUE
# 9992  2027050021          2   2705   21         1070      INTERVALE AVENUE
# 9993  2027050025          2   2705   25         1078      INTERVALE AVENUE
# 9994  4097640117          4   9764  117        87-23            160 STREET
# 9995  2032610091          2   3261   91         3160         BAILEY AVENUE
# 9996  2032160021          2   3216   21         1944  ANDREWS AVENUE SOUTH
# 9997  2024260001          2   2426    1          381       EAST 166 STREET
# 9998  2028490081          2   2849   81           63        CLIFFORD PLACE
#
#       ZIP_CODE  X_COORD  Y_COORD   LATITUDE  LONGITUDE BOROUGH  \
# 9989     10459  1012691   238311  40.820742 -73.897219   Bronx
# 9990     10459  1012673   238233  40.820474 -73.897292   Bronx
# 9991     10459  1012718   238880  40.822281 -73.897191   Bronx
# 9992     10459  1012861   239976  40.825313 -73.896491   Bronx
# 9993     10459  1012865   240063  40.825547 -73.896489   Bronx
# 9994     11432  1039216   197200  40.707774 -73.801744  Queens
# 9995     10463  1011423   259476  40.878840 -73.901741   Bronx
# 9996     10453  1008490   250758  40.854907 -73.913030   Bronx
# 9997     10456  1008570   241456  40.829389 -73.912123   Bronx
# 9998     10453  1008712   247532  40.846065 -73.911588   Bronx
#
#              INSPECTION_DATE        RESULT           APPROVED_DATE  \
# 9989  07/15/2010 10:39:47 AM  Bait applied  07/16/2010 09:55:15 AM
# 9990  07/15/2010 10:15:00 AM  Bait applied  07/16/2010 09:54:43 AM
# 9991  07/15/2010 10:47:50 AM  Bait applied  07/16/2010 09:54:09 AM
# 9992  07/15/2010 09:36:11 AM  Bait applied  07/16/2010 09:52:13 AM
# 9993  07/15/2010 09:53:54 AM  Bait applied  07/16/2010 09:50:35 AM
# 9994  07/15/2010 10:10:46 AM  Bait applied  07/15/2010 02:07:33 PM
# 9995  07/15/2010 12:16:29 PM  Bait applied  07/16/2010 09:49:36 AM
# 9996  07/15/2010 12:07:55 PM  Bait applied  07/16/2010 09:49:01 AM
# 9997  07/15/2010 10:09:31 AM  Bait applied  07/16/2010 09:47:50 AM
# 9998  07/15/2010 11:54:37 AM  Bait applied  07/16/2010 09:47:16 AM
#
#                                    LOCATION
# 9989  (40.8207420244034, -73.8972187135464)
# 9990  (40.8204738315909, -73.8972922812013)
# 9991  (40.8222812434217, -73.8971906702658)
# 9992    (40.82531300756, -73.8964910829487)
# 9993  (40.8255470401929, -73.8964886688692)
# 9994  (40.7077744363728, -73.8017444698633)
# 9995  (40.8788397683361, -73.9017406808259)
# 9996  (40.8549066197023, -73.9130302748932)
# 9997  (40.8293887213765, -73.9121234267685)
# 9998  (40.8460651323037, -73.9115881298086)

# %% [markdown]
# # exploring dataframes
# `pandas` has three defined data types: `Series`, `DataFrame`, and `Panel`. a `Series` is an array of objects of the same type, a `DataFrame` is an indexed table formed by a set of `Series`. a `Panel` is a collection of dataframes.
#
# we often want to select a part of the data rather having to deal with the whole table at a time. there are multiple ways to address a segment of the data. we might want a single column, a single row, a set of columns, a contiguous set of rows, a set of rows that satisfy some criteria, or a selection defined by a combination of these.

# %% [markdown]
# # selecting a dataframe column
# any individual column/series of a dataframe is mapped to a property of the dataframe. for instance, from the above we saw that the dataframe contains the `JOB_ID` property.

# %%
rodent_df.describe()

# %%
print(type(rodent_df.INSPECTION_TYPE)) # just the JOB_ID column
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# each column is a series object, and series objects have some built in methods for caclulating summaries of the values (the sum, mean, median, max, min, etc.). you can find out what these methods are with the `dir(object)` function.

# %%
lower_left  = (rodent_df.X_COORD.min(), rodent_df.Y_COORD.min())
upper_right = (rodent_df.X_COORD.max(), rodent_df.Y_COORD.max())
xrange = upper_right[0] - lower_left[0]
yrange = upper_right[1] - lower_left[1]
mid_point = (rodent_df.X_COORD.mean(), rodent_df.Y_COORD.mean())
med_point = (rodent_df.X_COORD.median(), rodent_df.Y_COORD.median())

# %%
rodent_df.X_COORD.describe() # try also .sum() function
# Out:
# count    9.999000e+03
# mean     1.276815e+06
# std      6.887182e+06
# min      0.000000e+00
# 25%      9.964650e+05
# 50%      1.003659e+06
# 75%      1.010183e+06
# max      2.434079e+08
# Name: X_COORD, dtype: float64

# %%
# we can also access individual columns by column name akin to dict key.
print('INSPECTION_TYPE details:')
print(rodent_df['INSPECTION_TYPE'].describe())
print('------')
print('JOB_ID details:')
print(rodent_df['JOB_ID'].describe())
print('------')
print('BOROUGH details')
print(rodent_df['BOROUGH'].describe())
print('there are', len(rodent_df['JOB_TICKET_OR_WORK_ORDER_ID'].unique()), 'unique job ticket ids')
# Out:
# INSPECTION_TYPE details:
# count     9999
# unique       1
# top       BAIT
# freq      9999
# Name: INSPECTION_TYPE, dtype: object
# ------
# JOB_ID details:
# count        9999
# unique       3800
# top       PO17708
# freq           14
# Name: JOB_ID, dtype: object
# ------
# BOROUGH details
# count      9999
# unique        5
# top       Bronx
# freq       3418
# Name: BOROUGH, dtype: object
# there are 9999 unique job ticket ids

# %%
# or a set/list of columns:
rodent_df[['JOB_ID', 'JOB_TICKET_OR_WORK_ORDER_ID', 'BOROUGH']].head()
# Out:
#     JOB_ID  JOB_TICKET_OR_WORK_ORDER_ID    BOROUGH
# 0  PO12965                            1  Manhattan
# 1  PO12966                            2  Manhattan
# 2  PO16966                           30      Bronx
# 3  PO13665                           31      Bronx
# 4  PO11291                           38  Manhattan

# %%
alist = ['JOB_ID', 'JOB_TICKET_OR_WORK_ORDER_ID', 'BOROUGH']
rodent_df[alist].head()
# note! what is wrong with this???
#rodent_df['JOB_ID', 'JOB_TICKET_OR_WORK_ORDER_ID'] # error!
# Out:
#     JOB_ID  JOB_TICKET_OR_WORK_ORDER_ID    BOROUGH
# 0  PO12965                            1  Manhattan
# 1  PO12966                            2  Manhattan
# 2  PO16966                           30      Bronx
# 3  PO13665                           31      Bronx
# 4  PO11291                           38  Manhattan

# %% [markdown]
# # selecting rows
# to select rows, we use either the `loc` or the `iloc` property. the former picks up rows by index and the latter by position in the dataframe.

# %%
rodent_df.loc[50]
# note the index column (Name:)
# Out:
# INSPECTION_TYPE                                                BAIT
# JOB_TICKET_OR_WORK_ORDER_ID                                     193
# JOB_ID                                                      PO15400
# JOB_PROGRESS                                                      3
# BBL                                                      1020880038
# BORO_CODE                                                         1
# BLOCK                                                          2088
# LOT                                                              38
# HOUSE_NUMBER                                                    610
# STREET_NAME                                         WEST 141 STREET
# ZIP_CODE                                                      10031
# X_COORD                                                      997302
# Y_COORD                                                      239524
# LATITUDE                                                    40.8241
# LONGITUDE                                                  -73.9528
# BOROUGH                                                   Manhattan
# INSPECTION_DATE                              12/01/2009 01:19:58 PM
# RESULT                                                 Bait applied
# APPROVED_DATE                                12/02/2009 01:30:51 PM
# LOCATION                       (40.824103930119, -73.9528407970262)
# Name: 50, dtype: object

# %%
# because for this dataframe the index is a just a row ordinal there is no difference between using `loc` and `iloc` 
rodent_df.iloc[50]
# Out:
# INSPECTION_TYPE                                                BAIT
# JOB_TICKET_OR_WORK_ORDER_ID                                     193
# JOB_ID                                                      PO15400
# JOB_PROGRESS                                                      3
# BBL                                                      1020880038
# BORO_CODE                                                         1
# BLOCK                                                          2088
# LOT                                                              38
# HOUSE_NUMBER                                                    610
# STREET_NAME                                         WEST 141 STREET
# ZIP_CODE                                                      10031
# X_COORD                                                      997302
# Y_COORD                                                      239524
# LATITUDE                                                    40.8241
# LONGITUDE                                                  -73.9528
# BOROUGH                                                   Manhattan
# INSPECTION_DATE                              12/01/2009 01:19:58 PM
# RESULT                                                 Bait applied
# APPROVED_DATE                                12/02/2009 01:30:51 PM
# LOCATION                       (40.824103930119, -73.9528407970262)
# Name: 50, dtype: object

# %%
# we can even select a number of rows:
rodent_df.loc[50:55]
# Out:
#    INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID   JOB_ID  JOB_PROGRESS  \
# 50            BAIT                          193  PO15400             3
# 51            BAIT                          199  PO16428             3
# 52            BAIT                          200  PO12863             3
# 53            BAIT                          201  PO10985             3
# 54            BAIT                          202  PO12163             3
# 55            BAIT                          205  PO28701             3
#
#            BBL  BORO_CODE  BLOCK  LOT HOUSE_NUMBER      STREET_NAME  ZIP_CODE  \
# 50  1020880038          1   2088   38          610  WEST 141 STREET     10031
# 51  2032080031          2   3208   31         2250  AQUEDUCT AVENUE     10453
# 52  4012420022          4   1242   22        33-34        70 STREET     11372
# 53  4014690050          4   1469   50        35-51        95 STREET     11372
# 54  4095870017          4   9587   17       104-36       134 STREET     11419
# 55  1012300025          1   1230   25          209   WEST 82 STREET     10024
#
#     X_COORD  Y_COORD   LATITUDE  LONGITUDE    BOROUGH         INSPECTION_DATE  \
# 50   997302   239524  40.824104 -73.952841  Manhattan  12/01/2009 01:19:58 PM
# 51  1009903   252202  40.858874 -73.907263      Bronx  12/02/2009 09:50:47 AM
# 52  1012966   213776  40.753396 -73.896354     Queens  12/03/2009 01:05:28 PM
# 53  1019565   213555  40.752765 -73.872537     Queens  12/03/2009 11:12:17 AM
# 54  1036263   191009  40.690799 -73.812443     Queens  12/03/2009 12:21:47 PM
# 55   990522   225382  40.785295 -73.977351  Manhattan  12/04/2009 02:09:10 PM
#
#           RESULT           APPROVED_DATE  \
# 50  Bait applied  12/02/2009 01:30:51 PM
# 51  Bait applied  12/07/2009 08:40:34 AM
# 52  Bait applied  12/09/2009 10:42:22 AM
# 53  Bait applied  12/14/2009 09:44:37 AM
# 54  Bait applied  12/09/2009 10:44:47 AM
# 55  Bait applied  12/07/2009 09:29:37 AM
#
#                                  LOCATION
# 50   (40.824103930119, -73.9528407970262)
# 51  (40.8588737119502, -73.9072626673015)
# 52  (40.7533955947211, -73.8963540872997)
# 53   (40.7527651129745, -73.872537219612)
# 54  (40.6907994771446, -73.8124433519563)
# 55  (40.7852954492163, -73.9773513556123)

# %%
rodent_df.iloc[50:55]
# Out:
#    INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID   JOB_ID  JOB_PROGRESS  \
# 50            BAIT                          193  PO15400             3
# 51            BAIT                          199  PO16428             3
# 52            BAIT                          200  PO12863             3
# 53            BAIT                          201  PO10985             3
# 54            BAIT                          202  PO12163             3
#
#            BBL  BORO_CODE  BLOCK  LOT HOUSE_NUMBER      STREET_NAME  ZIP_CODE  \
# 50  1020880038          1   2088   38          610  WEST 141 STREET     10031
# 51  2032080031          2   3208   31         2250  AQUEDUCT AVENUE     10453
# 52  4012420022          4   1242   22        33-34        70 STREET     11372
# 53  4014690050          4   1469   50        35-51        95 STREET     11372
# 54  4095870017          4   9587   17       104-36       134 STREET     11419
#
#     X_COORD  Y_COORD   LATITUDE  LONGITUDE    BOROUGH         INSPECTION_DATE  \
# 50   997302   239524  40.824104 -73.952841  Manhattan  12/01/2009 01:19:58 PM
# 51  1009903   252202  40.858874 -73.907263      Bronx  12/02/2009 09:50:47 AM
# 52  1012966   213776  40.753396 -73.896354     Queens  12/03/2009 01:05:28 PM
# 53  1019565   213555  40.752765 -73.872537     Queens  12/03/2009 11:12:17 AM
# 54  1036263   191009  40.690799 -73.812443     Queens  12/03/2009 12:21:47 PM
#
#           RESULT           APPROVED_DATE  \
# 50  Bait applied  12/02/2009 01:30:51 PM
# 51  Bait applied  12/07/2009 08:40:34 AM
# 52  Bait applied  12/09/2009 10:42:22 AM
# 53  Bait applied  12/14/2009 09:44:37 AM
# 54  Bait applied  12/09/2009 10:44:47 AM
#
#                                  LOCATION
# 50   (40.824103930119, -73.9528407970262)
# 51  (40.8588737119502, -73.9072626673015)
# 52  (40.7533955947211, -73.8963540872997)
# 53   (40.7527651129745, -73.872537219612)
# 54  (40.6907994771446, -73.8124433519563)

# %%
# and the selection need not be contiguous: 
row_indeces = [0,1,10,100]
rodent_df.iloc[row_indeces]
# Out:
#     INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID   JOB_ID  JOB_PROGRESS  \
# 0              BAIT                            1  PO12965             3
# 1              BAIT                            2  PO12966             3
# 10             BAIT                           51  PO11817             3
# 100            BAIT                          295  PO20835             3
#
#             BBL  BORO_CODE  BLOCK  LOT HOUSE_NUMBER     STREET_NAME  ZIP_CODE  \
# 0    1011470035          1   1147   35          104  WEST 76 STREET     10023
# 1    1011470034          1   1147   34          102  WEST 76 STREET     10023
# 10   1003770026          1    377   26          390   EAST 8 STREET     10009
# 100  2027960039          2   2796   39         1773    WEEKS AVENUE     10457
#
#      X_COORD  Y_COORD   LATITUDE  LONGITUDE    BOROUGH  \
# 0     990505   223527  40.780204 -73.977414  Manhattan
# 1     990516   223521  40.780188 -73.977375  Manhattan
# 10    990654   203066  40.724044 -73.976896  Manhattan
# 100  1009806   247554  40.846240 -73.907447      Bronx
#
#             INSPECTION_DATE        RESULT           APPROVED_DATE  \
# 0    10/14/2009 12:00:27 PM  Bait applied  10/14/2009 03:01:46 PM
# 1    10/14/2009 12:51:21 PM  Bait applied  10/14/2009 03:02:30 PM
# 10   11/16/2009 09:55:20 PM  Bait applied  11/19/2009 12:09:49 PM
# 100  12/14/2009 10:52:40 AM  Bait applied  12/15/2009 08:41:13 AM
#
#                                   LOCATION
# 0    (40.7802039792471, -73.9774144709456)
# 1     (40.7801875030438, -73.977374757787)
# 10    (40.7240436116555, -73.976895948583)
# 100  (40.8462399851237, -73.9074465419394)

# %%
# and we can even filter rows on some criteria
criteria = (rodent_df.BOROUGH == 'Manhattan') & (rodent_df.LONGITUDE < -73.950259)
#rodent_df.loc[row_indeces].filter(criteria)
rodent_df[criteria]
# Out:
#      INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID    JOB_ID  JOB_PROGRESS  \
# 0               BAIT                            1   PO12965             3
# 1               BAIT                            2   PO12966             3
# 4               BAIT                           38   PO11291             3
# 5               BAIT                           39   PO12483             3
# 10              BAIT                           51   PO11817             3
# 11              BAIT                           52   PO11077             3
# 12              BAIT                           53   PO15241             3
# 13              BAIT                           57   PO10580             3
# 14              BAIT                           58   PO13111             3
# 15              BAIT                           59   PO10759             3
# 16              BAIT                           60   PO11965             3
# 17              BAIT                           61   PO11019             3
# 22              BAIT                           84   PO12817             3
# 23              BAIT                           85   PO14758             3
# 24              BAIT                           88   PO11791             3
# 27              BAIT                          101   PO14335             3
# 28              BAIT                          103   PO10576             3
# 29              BAIT                          105   PO12629             3
# 34              BAIT                          145   PO14335             4
# 35              BAIT                          146   PO10576             4
# 36              BAIT                          147   PO12629             4
# 45              BAIT                          178   PO14937             3
# 47              BAIT                          188   PO28698             3
# 48              BAIT                          189   PO28696             3
# 50              BAIT                          193   PO15400             3
# 55              BAIT                          205   PO28701             3
# 68              BAIT                          234   PO15386             3
# 69              BAIT                          235   PO13857             3
# 70              BAIT                          237   PO13839             3
# 71              BAIT                          238   PO14824             3
# ...              ...                          ...       ...           ...
# 9866            BAIT                        23429   PO82989             3
# 9867            BAIT                        23431   PO71005             3
# 9868            BAIT                        23432   PO71008             3
# 9872            BAIT                        23452   PO75999             7
# 9873            BAIT                        23453   PO70916             6
# 9874            BAIT                        23454   PO76915             7
# 9875            BAIT                        23455   PO86075             7
# 9891            BAIT                        23481  PO123313             2
# 9892            BAIT                        23482  PO123314             2
# 9906            BAIT                        23498   PO91872             7
# 9907            BAIT                        23499   PO91787             5
# 9918            BAIT                        23514  PO101563             5
# 9921            BAIT                        23528   PO86501             6
# 9922            BAIT                        23529  PO103941             6
# 9923            BAIT                        23530   PO99447             6
# 9924            BAIT                        23531   PO99446             6
# 9925            BAIT                        23532   PO99445             6
# 9926            BAIT                        23533   PO85208             6
# 9953            BAIT                        23635   PO53110             3
# 9954            BAIT                        23637   PO54829             3
# 9955            BAIT                        23639   PO76945             3
# 9956            BAIT                        23640   PO77128             3
# 9957            BAIT                        23641   PO77118             3
# 9973            BAIT                        23671   PO63154             6
# 9974            BAIT                        23672   PO63195             5
# 9975            BAIT                        23673   PO83043             5
# 9976            BAIT                        23675   PO86856             5
# 9977            BAIT                        23676   PO83535             6
# 9978            BAIT                        23677   PO87843             6
# 9979            BAIT                        23678   PO99677             6
#
#              BBL  BORO_CODE  BLOCK  LOT HOUSE_NUMBER          STREET_NAME  \
# 0     1011470035          1   1147   35          104       WEST 76 STREET
# 1     1011470034          1   1147   34          102       WEST 76 STREET
# 4     1011690057          1   1169   57         2199             BROADWAY
# 5     1015340012          1   1534   12          232       EAST 89 STREET
# 10    1003770026          1    377   26          390        EAST 8 STREET
# 11    1003890019          1    389   19          202        EAST 7 STREET
# 12    1004590040          1    459   40           19        EAST 3 STREET
# 13    1002100005          1    210    5          336         CANAL STREET
# 14    1003920010          1    392   10          350       EAST 10 STREET
# 15    1004290001          1    429    1           12             1 AVENUE
# 16    1004420011          1    442   11           31        EAST 1 STREET
# 17    1004470009          1    447    9          306        EAST 6 STREET
# 22    1004510053          1    451   53          317        EAST 9 STREET
# 23    1004540031          1    454   31          342       EAST 13 STREET
# 24    1014680033          1   1468   33          486       EAST 74 STREET
# 27    1011290002          1   1129    2           57       WEST 76 STREET
# 28    1011540101          1   1154  101          249       WEST 62 STREET
# 29    1011650005          1   1165    5          269       WEST 73 STREET
# 34    1011290002          1   1129    2           57       WEST 76 STREET
# 35    1011540101          1   1154  101          249       WEST 62 STREET
# 36    1011650005          1   1165    5          269       WEST 73 STREET
# 45    1014060012          1   1406   12          127       EAST 71 STREET
# 47    1011500010          1   1150   10          153       WEST 78 STREET
# 48    1011500011          1   1150   11          151       WEST 78 STREET
# 50    1020880038          1   2088   38          610      WEST 141 STREET
# 55    1012300025          1   1230   25          209       WEST 82 STREET
# 68    1003450020          1    345   20          159         RIDGE STREET
# 69    1003530057          1    353   57          122       NORFOLK STREET
# 70    1004120010          1    412   10          190       ORCHARD STREET
# 71    1005910049          1    591   49           78   CHRISTOPHER STREET
# ...          ...        ...    ...  ...          ...                  ...
# 9866  1002730029          1    273   29          140         HENRY STREET
# 9867  1003550052          1    355   52          251  EAST HOUSTON STREET
# 9868  1003550057          1    355   57          265  EAST HOUSTON STREET
# 9872  1019670069          1   1967   69          405      WEST 127 STREET
# 9873  1020010060          1   2001   60          575      RIVERSIDE DRIVE
# 9874  1019690048          1   1969   48           49  ST NICHOLAS TERRACE
# 9875  1019880024          1   1988   24          509      WEST 134 STREET
# 9891  1010360149          1   1036  149          338       WEST 46 STREET
# 9892  1010360052          1   1036   52          346       WEST 46 STREET
# 9906  1018210051          1   1821   51          126      WEST 112 STREET
# 9907  1018240014          1   1824   14           80   ST NICHOLAS AVENUE
# 9918  1016250010          1   1625   10          121       EAST 97 STREET
# 9921  1003920037          1    392   37          145             AVENUE C
# 9922  1004370040          1    437   40          425        EAST 9 STREET
# 9923  1004370044          1    437   44          417        EAST 9 STREET
# 9924  1004370045          1    437   45          415        EAST 9 STREET
# 9925  1004370046          1    437   46          413        EAST 9 STREET
# 9926  1003940044          1    394   44          181             AVENUE C
# 9953  1003000021          1    300   21           33         ALLEN STREET
# 9954  1003040021          1    304   21          249         GRAND STREET
# 9955  1006390001          1    639    1          445          WEST STREET
# 9956  1006430049          1    643   49           52    GANSEVOORT STREET
# 9957  1006430069          1    643   69           79       HORATIO STREET
# 9973  1005670013          1    567   13           14       EAST 10 STREET
# 9974  1005690032          1    569   32           23       EAST 11 STREET
# 9975  1002750022          1    275   22           30        MARKET STREET
# 9976  1002800022          1    280   22           15        MARKET STREET
# 9977  1003900057          1    390   57          197        EAST 7 STREET
# 9978  1003950003          1    395    3          199             AVENUE B
# 9979  1004320001          1    432    1           66             1 AVENUE
#
#       ZIP_CODE  X_COORD  Y_COORD   LATITUDE  LONGITUDE    BOROUGH  \
# 0        10023   990505   223527  40.780204 -73.977414  Manhattan
# 1        10023   990516   223521  40.780188 -73.977375  Manhattan
# 4        10024   989641   224567  40.783059 -73.980533  Manhattan
# 5        10128   997617   223597  40.780388 -73.951734  Manhattan
# 10       10009   990654   203066  40.724044 -73.976896  Manhattan
# 11       10009   989741   203281  40.724634 -73.980190  Manhattan
# 12       10003   986804   203770  40.725978 -73.990786  Manhattan
# 13       10013   983586   201500  40.719748 -74.002395  Manhattan
# 14       10009   989987   203999  40.726605 -73.979302  Manhattan
# 15       10009   987488   202831  40.723400 -73.988318  Manhattan
# 16       10003   986933   203069  40.724054 -73.990320  Manhattan
# 17       10003   987552   204216  40.727202 -73.988087  Manhattan
# 22       10003   987961   204844  40.728925 -73.986611  Manhattan
# 23       10003   988579   205673  40.731200 -73.984380  Manhattan
# 24       10021   997179   219224  40.768386 -73.953324  Manhattan
# 27       10023   991001   223260  40.779471 -73.975624  Manhattan
# 28       10023   987539   221028  40.773346 -73.988125  Manhattan
# 29       10023   988921   223504  40.780142 -73.983134  Manhattan
# 34       10023   991001   223260  40.779471 -73.975624  Manhattan
# 35       10023   987539   221028  40.773346 -73.988125  Manhattan
# 36       10023   988921   223504  40.780142 -73.983134  Manhattan
# 45       10021   994400   219820  40.770026 -73.963356  Manhattan
# 47       10024   990493   224144  40.781897 -73.977457  Manhattan
# 48       10024   990504   224138  40.781881 -73.977418  Manhattan
# 50       10031   997302   239524  40.824104 -73.952841  Manhattan
# 55       10024   990522   225382  40.785295 -73.977351  Manhattan
# 68       10002   989114   201749  40.720430 -73.982453  Manhattan
# 69       10002   987882   201326  40.719269 -73.986898  Manhattan
# 70       10002   987532   202366  40.722124 -73.988160  Manhattan
# 71       10014   983253   206508  40.733493 -74.003597  Manhattan
# ...        ...      ...      ...        ...        ...        ...
# 9866     10002   986864   199120  40.713333 -73.990625  Manhattan
# 9867     10002   988303   202177  40.721893 -73.985234  Manhattan
# 9868     10002   988417   202136  40.721778 -73.984862  Manhattan
# 9872     10027   997105   235497  40.812854 -73.953492  Manhattan
# 9873     10031   995946   238308  40.821087 -73.957616  Manhattan
# 9874     10027   997781   235791  40.813857 -73.951118  Manhattan
# 9875     10031   997181   237475  40.818480 -73.953282  Manhattan
# 9891     10036   987262   216270  40.760293 -73.989134  Manhattan
# 9892     10036   987218   216295  40.760362 -73.989293  Manhattan
# 9906     10026   997165   230721  40.799963 -73.953332  Manhattan
# 9907     10026   997479   231306  40.801561 -73.952213  Manhattan
# 9918     10029   997831   226010  40.787008 -73.950945  Manhattan
# 9921     10009   990299   203606  40.725532 -73.978182  Manhattan
# 9922     10009   988793   204426  40.727864 -73.983568  Manhattan
# 9923     10009   988714   204471  40.727988 -73.983836  Manhattan
# 9924     10009   988709   204512  40.728020 -73.983914  Manhattan
# 9925     10009   988671   204494  40.728054 -73.983995  Manhattan
# 9926     10009   990534   204035  40.726618 -73.976992  Manhattan
# 9953     10002   986357   200112  40.715883 -73.992086  Manhattan
# 9954     10002   985856   200870  40.718238 -73.994152  Manhattan
# 9955     10014   981751   207531  40.736147 -74.010013  Manhattan
# 9956     10014   982286   208572  40.739389 -74.006928  Manhattan
# 9957     10014   982183   208492  40.738766 -74.007444  Manhattan
# 9973     10003   985727   206305  40.733076 -73.994656  Manhattan
# 9974     10003   985935   206588  40.733619 -73.994046  Manhattan
# 9975     10002   985837   198949  40.712726 -73.994409  Manhattan
# 9976     10002   985684   199112  40.713213 -73.994803  Manhattan
# 9977     10009   989711   203341  40.724805 -73.980304  Manhattan
# 9978     10009   990183   204601  40.728263 -73.978600  Manhattan
# 9979     10009   988256   203506  40.725350 -73.985552  Manhattan
#
#              INSPECTION_DATE        RESULT           APPROVED_DATE  \
# 0     10/14/2009 12:00:27 PM  Bait applied  10/14/2009 03:01:46 PM
# 1     10/14/2009 12:51:21 PM  Bait applied  10/14/2009 03:02:30 PM
# 4     11/10/2009 08:40:42 AM  Bait applied  11/17/2009 11:39:11 AM
# 5     11/10/2009 09:53:06 AM  Bait applied  11/17/2009 11:39:42 AM
# 10    11/16/2009 09:55:20 PM  Bait applied  11/19/2009 12:09:49 PM
# 11    11/16/2009 10:20:14 PM  Bait applied  11/23/2009 12:11:55 PM
# 12    11/16/2009 09:25:46 PM  Bait applied  11/19/2009 12:04:34 PM
# 13    11/17/2009 12:00:29 PM  Bait applied  11/23/2009 12:16:37 PM
# 14    11/17/2009 09:55:24 AM  Bait applied  11/23/2009 12:07:54 PM
# 15    11/17/2009 10:30:04 AM  Bait applied  11/23/2009 02:11:19 PM
# 16    11/17/2009 11:02:47 AM  Bait applied  11/19/2009 08:10:36 AM
# 17    11/17/2009 09:20:23 AM  Bait applied  11/19/2009 08:21:54 AM
# 22    11/20/2009 09:23:04 AM  Bait applied  11/23/2009 12:04:48 PM
# 23    11/20/2009 09:50:22 AM  Bait applied  11/23/2009 11:28:57 AM
# 24    11/20/2009 10:35:30 PM  Bait applied  11/23/2009 11:33:28 AM
# 27    11/23/2009 10:55:40 AM  Bait applied  11/24/2009 03:54:45 PM
# 28    11/23/2009 09:55:08 AM  Bait applied  11/24/2009 03:57:02 PM
# 29    11/23/2009 10:30:25 AM  Bait applied  11/24/2009 04:00:12 PM
# 34    11/25/2009 11:20:49 AM  Bait applied  11/27/2009 12:08:52 PM
# 35    11/25/2009 10:05:47 AM  Bait applied  11/27/2009 12:11:04 PM
# 36    11/25/2009 10:45:30 AM  Bait applied  11/27/2009 12:13:10 PM
# 45    11/30/2009 09:44:21 AM  Bait applied  11/30/2009 03:38:01 PM
# 47    12/01/2009 11:40:14 AM  Bait applied  12/02/2009 01:25:00 PM
# 48    12/01/2009 12:00:10 PM  Bait applied  12/02/2009 01:25:56 PM
# 50    12/01/2009 01:19:58 PM  Bait applied  12/02/2009 01:30:51 PM
# 55    12/04/2009 02:09:10 PM  Bait applied  12/07/2009 09:29:37 AM
# 68    12/07/2009 10:45:52 PM  Bait applied  12/08/2009 10:52:59 AM
# 69    12/07/2009 12:05:54 PM  Bait applied  12/08/2009 10:54:21 AM
# 70    12/07/2009 10:15:20 PM  Bait applied  12/08/2009 11:00:36 AM
# 71    12/07/2009 09:10:42 PM  Bait applied  12/08/2009 11:28:00 AM
# ...                      ...           ...                     ...
# 9866  07/13/2010 10:26:44 AM  Bait applied  07/14/2010 01:05:41 PM
# 9867  07/13/2010 09:30:26 AM  Bait applied  07/14/2010 01:04:37 PM
# 9868  07/13/2010 09:38:59 AM  Bait applied  07/14/2010 01:04:05 PM
# 9872  07/13/2010 12:17:15 PM  Bait applied  07/13/2010 04:21:48 PM
# 9873  07/13/2010 12:32:32 PM  Bait applied  07/13/2010 04:21:14 PM
# 9874  07/13/2010 11:53:50 AM  Bait applied  07/13/2010 04:20:42 PM
# 9875  07/13/2010 11:35:45 AM  Bait applied  07/13/2010 04:20:01 PM
# 9891  07/13/2010 01:10:58 PM  Bait applied  07/13/2010 04:00:47 PM
# 9892  07/13/2010 01:05:02 PM  Bait applied  07/13/2010 04:00:17 PM
# 9906  07/13/2010 10:19:52 AM  Bait applied  07/13/2010 02:50:54 PM
# 9907  07/13/2010 10:12:00 AM  Bait applied  07/13/2010 02:50:10 PM
# 9918  07/13/2010 09:37:13 AM  Bait applied  07/13/2010 03:01:04 PM
# 9921  07/13/2010 11:35:37 AM  Bait applied  07/14/2010 12:58:20 PM
# 9922  07/13/2010 11:48:04 AM  Bait applied  07/14/2010 12:57:53 PM
# 9923  07/13/2010 11:03:57 AM  Bait applied  07/14/2010 12:57:23 PM
# 9924  07/13/2010 12:03:42 PM  Bait applied  07/14/2010 12:56:56 PM
# 9925  07/13/2010 12:08:33 PM  Bait applied  07/14/2010 12:56:24 PM
# 9926  07/13/2010 11:15:04 AM  Bait applied  07/14/2010 12:55:49 PM
# 9953  07/14/2010 10:50:47 AM  Bait applied  07/15/2010 09:37:08 AM
# 9954  07/14/2010 10:23:09 AM  Bait applied  07/15/2010 09:36:15 AM
# 9955  07/14/2010 11:30:49 AM  Bait applied  07/15/2010 09:35:09 AM
# 9956  07/14/2010 11:43:06 AM  Bait applied  07/15/2010 09:34:37 AM
# 9957  07/14/2010 12:00:06 PM  Bait applied  07/15/2010 09:34:03 AM
# 9973  07/14/2010 01:48:56 PM  Bait applied  07/15/2010 09:30:53 AM
# 9974  07/14/2010 01:35:24 PM  Bait applied  07/15/2010 09:29:17 AM
# 9975  07/14/2010 01:08:28 PM  Bait applied  07/15/2010 09:28:44 AM
# 9976  07/14/2010 12:55:50 PM  Bait applied  07/15/2010 09:26:29 AM
# 9977  07/14/2010 12:24:16 PM  Bait applied  07/15/2010 09:25:53 AM
# 9978  07/14/2010 12:10:23 PM  Bait applied  07/15/2010 09:25:13 AM
# 9979  07/14/2010 12:38:00 PM  Bait applied  07/15/2010 09:22:12 AM
#
#                                    LOCATION
# 0     (40.7802039792471, -73.9774144709456)
# 1      (40.7801875030438, -73.977374757787)
# 4     (40.7830590725833, -73.9805333640688)
# 5      (40.780388216313, -73.9517343542567)
# 10     (40.7240436116555, -73.976895948583)
# 11     (40.7246343483455, -73.980189651703)
# 12    (40.7259778701156, -73.9907855310067)
# 13    (40.7197476131092, -74.0023953936767)
# 14     (40.726604927718, -73.9793015244998)
# 15    (40.7234003190272, -73.9883182080389)
# 16    (40.7240537571041, -73.9903203968151)
# 17    (40.7272017839871, -73.9880866345106)
# 22    (40.7289253286763, -73.9866106472347)
# 23    (40.7312004499725, -73.9843803591535)
# 24     (40.768386131078, -73.9533243006866)
# 27    (40.7794707699529, -73.9756237844939)
# 28      (40.77334648331, -73.9881253149363)
# 29    (40.7801418293715, -73.9831339876533)
# 34    (40.7794707699529, -73.9756237844939)
# 35      (40.77334648331, -73.9881253149363)
# 36    (40.7801418293715, -73.9831339876533)
# 45    (40.7700256234917, -73.9633560211574)
# 47    (40.7818974891994, -73.9774572271653)
# 48    (40.7818810130151, -73.9774175129861)
# 50     (40.824103930119, -73.9528407970262)
# 55    (40.7852954492163, -73.9773513556123)
# 68     (40.7204297458774, -73.982452840106)
# 69    (40.7192693043524, -73.9868975791748)
# 70    (40.7221239903094, -73.9881596951899)
# 71     (40.733493323144, -74.0035974399873)
# ...                                     ...
# 9866  (40.7133327512673, -73.9906249562999)
# 9867  (40.7218930925515, -73.9852339427882)
# 9868  (40.7217777644433, -73.9848623823946)
# 9872  (40.8128535907826, -73.9534918059668)
# 9873   (40.821086595098, -73.9576157278293)
# 9874  (40.8138571766811, -73.9511176117635)
# 9875  (40.8184801827696, -73.9532819399571)
# 9891  (40.7602931306354, -73.9891341205071)
# 9892  (40.7603617639118, -73.9892929445892)
# 9906  (40.7999632896217, -73.9533320391231)
# 9907  (40.8015612112671, -73.9522134671714)
# 9918  (40.7870075230996, -73.9509451964688)
# 9921  (40.7255321491722, -73.9781822743802)
# 9922  (40.7278643344964, -73.9835681495166)
# 9923  (40.7279876822944, -73.9838364382902)
# 9924  (40.7280203426192, -73.9839139480638)
# 9925  (40.7280542951699, -73.9839945258704)
# 9926  (40.7266182132684, -73.9769924690834)
# 9953  (40.7158827440147, -73.9920855587536)
# 9954  (40.7182378718018, -73.9941523415723)
# 9955  (40.7361471206919, -74.0100133335844)
# 9956  (40.7393889002389, -74.0069284813983)
# 9957  (40.7387658093523, -74.0074444393015)
# 9973  (40.7330760527151, -73.9946561933202)
# 9974   (40.7336194841174, -73.994046351835)
# 9975  (40.7127264049032, -73.9944089320782)
# 9976  (40.7132134151726, -73.9948033151718)
# 9977  (40.7248051728811, -73.9803039967851)
# 9978  (40.7282632531992, -73.9785999260222)
# 9979    (40.72535029277, -73.9855517259032)
#
# [1481 rows x 20 columns]

# %% [markdown]
# # selecting individual cells
# as with a matrix in linear algebra, an individual value can be addresses by its coordinates (row, column) note that this is opposite of how values are addressed in excel: <column><row>, e.g. B4.  by use of the `iloc` property.
#
# for instance the value in the 3rd row, 4th column is accessed with `rodent_df.iloc[2,3]` (remember that the indeces start off from 0).

# %%
print('the value in the 3rd, row, 5th column is:', rodent_df.iloc[2,4])
rodent_df.head()
# Out:
# the value in the 3rd, row, 5th column is: 2043370027
#   INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID   JOB_ID  JOB_PROGRESS  \
# 0            BAIT                            1  PO12965             3
# 1            BAIT                            2  PO12966             3
# 2            BAIT                           30  PO16966             3
# 3            BAIT                           31  PO13665             3
# 4            BAIT                           38  PO11291             3
#
#           BBL  BORO_CODE  BLOCK  LOT HOUSE_NUMBER       STREET_NAME  ZIP_CODE  \
# 0  1011470035          1   1147   35          104    WEST 76 STREET     10023
# 1  1011470034          1   1147   34          102    WEST 76 STREET     10023
# 2  2043370027          2   4337   27          620    THWAITES PLACE     10467
# 3  2037670077          2   3767   77         1227  WHITEPLAINS ROAD     10472
# 4  1011690057          1   1169   57         2199          BROADWAY     10024
#
#    X_COORD  Y_COORD   LATITUDE  LONGITUDE    BOROUGH         INSPECTION_DATE  \
# 0   990505   223527  40.780204 -73.977414  Manhattan  10/14/2009 12:00:27 PM
# 1   990516   223521  40.780188 -73.977375  Manhattan  10/14/2009 12:51:21 PM
# 2  1020110   252216  40.858877 -73.870364      Bronx  11/09/2009 12:59:55 PM
# 3  1022441   242180  40.831321 -73.861994      Bronx  11/09/2009 11:10:16 AM
# 4   989641   224567  40.783059 -73.980533  Manhattan  11/10/2009 08:40:42 AM
#
#          RESULT           APPROVED_DATE                               LOCATION
# 0  Bait applied  10/14/2009 03:01:46 PM  (40.7802039792471, -73.9774144709456)
# 1  Bait applied  10/14/2009 03:02:30 PM   (40.7801875030438, -73.977374757787)
# 2  Bait applied  11/10/2009 02:54:52 PM  (40.8588765781972, -73.8703636422023)
# 3  Bait applied  11/10/2009 02:56:42 PM   (40.8313209626148, -73.861994089899)
# 4  Bait applied  11/17/2009 11:39:11 AM  (40.7830590725833, -73.9805333640688)

# %%
rodent_df.iloc[2:5,4:7]
# Out:
#           BBL  BORO_CODE  BLOCK
# 2  2043370027          2   4337
# 3  2037670077          2   3767
# 4  1011690057          1   1169

# %% [markdown]
# # a note on indeces
# note that the first column, the row index, is by default an ordinal number from 0 to N-1. we can identify rows by this index, redefine it to be any unique-valued series of equal length. in this case, for instance we note that each row (each observation) is an inspection job, each of which has its own job id. for some use cases it would make sense to index the table on the job id instead. let's see how that could be done:

# %%
rodent_df.index = rodent_df.JOB_TICKET_OR_WORK_ORDER_ID
rodent_df.head()
# Out:
#                             INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                                      BAIT                            1
# 2                                      BAIT                            2
# 30                                     BAIT                           30
# 31                                     BAIT                           31
# 38                                     BAIT                           38
#
#                               JOB_ID  JOB_PROGRESS         BBL  BORO_CODE  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                            PO12965             3  1011470035          1
# 2                            PO12966             3  1011470034          1
# 30                           PO16966             3  2043370027          2
# 31                           PO13665             3  2037670077          2
# 38                           PO11291             3  1011690057          1
#
#                              BLOCK  LOT HOUSE_NUMBER       STREET_NAME  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                             1147   35          104    WEST 76 STREET
# 2                             1147   34          102    WEST 76 STREET
# 30                            4337   27          620    THWAITES PLACE
# 31                            3767   77         1227  WHITEPLAINS ROAD
# 38                            1169   57         2199          BROADWAY
#
#                              ZIP_CODE  X_COORD  Y_COORD   LATITUDE  LONGITUDE  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                               10023   990505   223527  40.780204 -73.977414
# 2                               10023   990516   223521  40.780188 -73.977375
# 30                              10467  1020110   252216  40.858877 -73.870364
# 31                              10472  1022441   242180  40.831321 -73.861994
# 38                              10024   989641   224567  40.783059 -73.980533
#
#                                BOROUGH         INSPECTION_DATE        RESULT  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                            Manhattan  10/14/2009 12:00:27 PM  Bait applied
# 2                            Manhattan  10/14/2009 12:51:21 PM  Bait applied
# 30                               Bronx  11/09/2009 12:59:55 PM  Bait applied
# 31                               Bronx  11/09/2009 11:10:16 AM  Bait applied
# 38                           Manhattan  11/10/2009 08:40:42 AM  Bait applied
#
#                                       APPROVED_DATE  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                            10/14/2009 03:01:46 PM
# 2                            10/14/2009 03:02:30 PM
# 30                           11/10/2009 02:54:52 PM
# 31                           11/10/2009 02:56:42 PM
# 38                           11/17/2009 11:39:11 AM
#
#                                                           LOCATION
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                            (40.7802039792471, -73.9774144709456)
# 2                             (40.7801875030438, -73.977374757787)
# 30                           (40.8588765781972, -73.8703636422023)
# 31                            (40.8313209626148, -73.861994089899)
# 38                           (40.7830590725833, -73.9805333640688)

# %% [markdown]
# note the difference? now there is a difference between the `loc` and `iloc` methods:

# %%
print('loc[2]: ', rodent_df['JOB_ID'].loc[2])
print('iloc[2]:', rodent_df['JOB_ID'].iloc[2])
# Out:
# loc[2]:  PO12966
# iloc[2]: PO16966

# %% [markdown]
# # aggregating
# we often want to calculate summary statistics of similar sections dataframe, we do this by first _grouping by_ a column value, and then _aggregating_ the values in each group. e.g. here we might want to know how many inspections there are in each borough. to do that we need to group by the borough column values and aggregating all the rows for each borough with the `count()` function.

# %%
rodent_df.groupby('BOROUGH').agg({'BOROUGH':'count'})
# Out:
#                BOROUGH
# BOROUGH
# Bronx             3418
# Brooklyn          3045
# Manhattan         2707
# Queens             603
# Staten Island      226

# %% [markdown]
# note that the output is a dataframe, indexed on the categorical column we grouped by.

# %%
type(rodent_df.groupby('BOROUGH').agg({'BOROUGH':'count'}))

# %% [markdown]
# the above form works for any aggregation function. but in case you are just doing a count of rows, and especially if you have a large dataframe, you might prefer to use the `value_counts()` function which has been optimised.

# %%
rodent_df['BOROUGH'].value_counts(dropna=False)
# Out:
# Bronx            3418
# Brooklyn         3045
# Manhattan        2707
# Queens            603
# Staten Island     226
# Name: BOROUGH, dtype: int64

# %% [markdown]
# note that the outut from `value_counts()` is a series, not a dataframe.

# %%
type(rodent_df['BOROUGH'].value_counts(dropna=False))
# Out:
# pandas.core.series.Series

# %% [markdown]
# # back to the exercise:
# we now have all the features in place we need to answer the questions set out in today's exercise. we start by copying over a solution to last exercise (to read and manipulate the new york rodent inspection data).

# %%
# let us define this utility function for formatting an iso-week:
def format_iso_week(datetime_obj):
    the_date = datetime_obj.date()
    iso_year, iso_week, iso_weekday = the_date.isocalendar()
    iso_week_str = str(iso_year) + '-W' + str(iso_week)
    return iso_week_str

# %%
# the columns of interest is the 'INSPECTION_DATE' and 'APPROVED_DATE'
# inspection by eye gives us the datetime format descriptor
format_descriptor = '%m/%d/%Y %I:%M:%S %p'

rodent_df['inspection_datetime']   = rodent_df.apply(lambda row: datetime.datetime.strptime(row['INSPECTION_DATE'], format_descriptor), axis=1)
rodent_df['approval_datetime']     = rodent_df.apply(lambda row: datetime.datetime.strptime(row['APPROVED_DATE'],   format_descriptor), axis=1)
rodent_df['wait_time_to_approval'] = rodent_df.apply(lambda row: (row['approval_datetime'] - row['inspection_datetime']).total_seconds(),axis=1)
rodent_df['inspection_month']      = rodent_df.apply(lambda row: row['inspection_datetime'].strftime("%B"),   axis=1)
rodent_df['isoweek']               = rodent_df.apply(lambda row: format_iso_week(row['inspection_datetime']), axis=1)
rodent_df['inspection_weekday']    = rodent_df.apply(lambda row: row['inspection_datetime'].strftime("%A"),   axis=1)
rodent_df.head()
# Out:
#                             INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                                      BAIT                            1
# 2                                      BAIT                            2
# 30                                     BAIT                           30
# 31                                     BAIT                           31
# 38                                     BAIT                           38
#
#                               JOB_ID  JOB_PROGRESS         BBL  BORO_CODE  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                            PO12965             3  1011470035          1
# 2                            PO12966             3  1011470034          1
# 30                           PO16966             3  2043370027          2
# 31                           PO13665             3  2037670077          2
# 38                           PO11291             3  1011690057          1
#
#                              BLOCK  LOT HOUSE_NUMBER       STREET_NAME  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                             1147   35          104    WEST 76 STREET
# 2                             1147   34          102    WEST 76 STREET
# 30                            4337   27          620    THWAITES PLACE
# 31                            3767   77         1227  WHITEPLAINS ROAD
# 38                            1169   57         2199          BROADWAY
#
#                                    ...                 INSPECTION_DATE  \
# JOB_TICKET_OR_WORK_ORDER_ID        ...
# 1                                  ...          10/14/2009 12:00:27 PM
# 2                                  ...          10/14/2009 12:51:21 PM
# 30                                 ...          11/09/2009 12:59:55 PM
# 31                                 ...          11/09/2009 11:10:16 AM
# 38                                 ...          11/10/2009 08:40:42 AM
#
#                                    RESULT           APPROVED_DATE  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                            Bait applied  10/14/2009 03:01:46 PM
# 2                            Bait applied  10/14/2009 03:02:30 PM
# 30                           Bait applied  11/10/2009 02:54:52 PM
# 31                           Bait applied  11/10/2009 02:56:42 PM
# 38                           Bait applied  11/17/2009 11:39:11 AM
#
#                                                           LOCATION  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                            (40.7802039792471, -73.9774144709456)
# 2                             (40.7801875030438, -73.977374757787)
# 30                           (40.8588765781972, -73.8703636422023)
# 31                            (40.8313209626148, -73.861994089899)
# 38                           (40.7830590725833, -73.9805333640688)
#
#                              inspection_datetime   approval_datetime  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                            2009-10-14 12:00:27 2009-10-14 15:01:46
# 2                            2009-10-14 12:51:21 2009-10-14 15:02:30
# 30                           2009-11-09 12:59:55 2009-11-10 14:54:52
# 31                           2009-11-09 11:10:16 2009-11-10 14:56:42
# 38                           2009-11-10 08:40:42 2009-11-17 11:39:11
#
#                             wait_time_to_approval inspection_month   isoweek  \
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                                         10879.0          October  2009-W42
# 2                                          7869.0          October  2009-W42
# 30                                        93297.0         November  2009-W46
# 31                                        99986.0         November  2009-W46
# 38                                       615509.0         November  2009-W46
#
#                             inspection_weekday
# JOB_TICKET_OR_WORK_ORDER_ID
# 1                                    Wednesday
# 2                                    Wednesday
# 30                                      Monday
# 31                                      Monday
# 38                                     Tuesday
#
# [5 rows x 26 columns]

# %%
earliest_date = rodent_df['inspection_datetime'].min()
latest_date = rodent_df['inspection_datetime'].max()
print('the inspection dates range from', earliest_date, 'to', latest_date)
# Out:
# the inspection dates range from 2009-01-16 10:04:24 to 2011-10-27 18:28:10

# %% [markdown]
# # solution to exercise

# %%
start_date = pd.to_datetime('2010-01-01')
end_date = pd.to_datetime('2010-03-31')
criteria = (rodent_df.inspection_datetime >= start_date) & (rodent_df.inspection_datetime <= end_date)
print('there are', sum(criteria), 'rows selected')
# Out:
# there are 3406 rows selected

# %%
rodent_df[['inspection_datetime', 'inspection_weekday']].sort_values('inspection_datetime').groupby('inspection_weekday').agg({'inspection_weekday':'count'})
# Out:
#                     inspection_weekday
# inspection_weekday
# Friday                            1750
# Monday                            1824
# Saturday                           359
# Sunday                             342
# Thursday                          1927
# Tuesday                           2065
# Wednesday                         1732

# %%
rodent_df['inspection_month'].value_counts()
# Out:
# April       2243
# June        2062
# March       1784
# May         1509
# February     928
# January      785
# July         438
# December     202
# November      45
# October        3
# Name: inspection_month, dtype: int64
